# %%
import random
p = random.random()
print(p)
# Out:
# 0.9891022545398666

# %%
import numpy as np
data = np.load('./datasets/protues_train_WFHAPaug.npz')
print(data.files)
np.set_printoptions(threshold=np.inf)
print(data['x_train'][2])
# Out:
# ['x_train', 'y_train']
# [0.92362845 1.         0.99607223 0.98941654 0.9798546  0.9671048
#  0.95074016 0.9301146  0.90423656 0.87157005 0.8299365  0.7787876
#  0.7390009  0.75302494 0.78341204 0.80428636 0.8150646  0.81752264
#  0.8126618  0.80061185 0.7805613  0.7502643  0.70453155 0.6331246
#  0.5929649  0.66354954 0.711928   0.7408529  0.7582013  0.7676468
#  0.77102464 0.7692926  0.7629124  0.7520028  0.7363807  0.71552193
#  0.68843263 0.65340346 0.6078395  0.5513832  0.51400983 0.5355685
#  0.5635934  0.5789317  0.58288026 0.5774104  0.5640224  0.5453805
#  0.5289164  0.5267455  0.54006726 0.5576404  0.57240504 0.5833222
#  0.59221613 0.60213727 0.6156441  0.63292176 0.65191895 0.6702101
#  0.68614876 0.6988843  0.70803076 0.7133992  0.71484256 0.71216935
#  0.7050927  0.69321084 0.6760755  0.65363055 0.62804675 0.60847664
#  0.60896677 0.6261246  0.64542073 0.66007406 0.6686668  0.6711337
#  0.66744494 0.6572152  0.6394565  0.6122132  0.57225925 0.5206353
# ...

# %%
from WFHAP1AUG.py import Augmentor
A = Augmentor()
x1 = data['x_train'][0]
x1_f = A.frequency_get(x1)
print(x1_f)
# Out:
# Device: cuda:0
# Generating WFHAP augmented dataset...
#   2%|▏         | 510/28599 [00:02<02:30, 186.37it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from WFHAP1AUG.py import Augmentor
#       2 A = Augmentor()
#       3 x1 = data['x_train'][0]
#
# File ~/autodl-tmp/WF-HAP/WFHAP1AUG.py:383
#     380 label = y_train[i]
#     382 # 调用主方法，一次性得到4条样本 shape=(4,10000)
# --> 383 four_samples = aug_tool.augmentor(trace)
#     385 # 填入数组：第4*i、4*i+1、4*i+2、4*i+3 分别对应四类样本
#     386 x_train_aug[4*i]     = four_samples[0]  # 原轨迹 10000
#
# File ~/autodl-tmp/WF-HAP/WFHAP1AUG.py:332, in Augmentor.augmentor(self, trace)
#     329 trace_time_aug = self.augment_time(trace)
#     331 # 3. 原始频谱 + 补0到10000
# --> 332 spec_raw_5k = self.frequency_get(trace)
#     333 spec_raw_10k = self.pad_spec_to_full(spec_raw_5k)
#     335 # 4. 频谱增强 + 补0到10000
#
# ...
